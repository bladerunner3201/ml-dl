# %%
import numpy as np
import tensorflow as tf
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D
from keras.layers import Flatten, Dense, Dropout
# Out:
# d:\workplace_00\.venv\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
(x_tr, y_tr), (x_tst, y_tst) = cifar10.load_data()

x_tr = x_tr.reshape(-1, 32, 32, 3)
x_tst = x_tst.reshape(-1, 32, 32, 3)

print(x_tr.shape, x_tst.shape)
print(y_tr.shape, y_tst.shape)

x_tr = x_tr.astype(np.float32) / 255.0
x_tst = x_tst.astype(np.float32) / 255.0
# Out:
# (50000, 32, 32, 3) (10000, 32, 32, 3)
# (50000, 1) (10000, 1)
