# %% [markdown]
# 1. `cars` 데이터셋을 이용하여 회귀모형을 만들고 모형의 평가 수치를 확인하고 영향도 정보를 확인하세요.
#
#     - 데이터셋의 로드는 `statsmodels` 패키지를 이용하세요.
#     - 결정계수는 얼마인가요?
#     - 회귀식은 어떻게 되나요?
#     - 잔차의 독립성이 있다고 판단됩니까?
#     - P-P 도표를 그리세요.
#     - 영향도 정보를 데이터프레임으로 출력하세요.
#     - 레버리지와 표준화된 잔차를 이용해 산점도를 출력하세요.

# %%
# R의 'datasets' 패키지에 있는 'cars' 데이터를 가져옵니다.
cars = sm.datasets.get_rdataset("cars", package="datasets")
cars_df = cars.data
